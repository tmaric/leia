# %% [markdown]
# # 3D shear of a sphere

# %%
from advectionplot import *

# %% [markdown]
# # Error definitions
#
# ## Phase indicator (marker) - initial error
#
# #### Convergence rate for $\frac{|V(t_0) - V_e|}{V_e}$,  $V(t_0) := \sum_{c \in C} \alpha_c |\Omega_c|$,  $V_e$ is the exact volume.
#
# **Note the exact volume is not read from system/fvSolution, sphere of $R=0.15$ is used here and needs to match system/fvSolution.**
#
# ## Advection errors
#
# ### Ev: volume conservation error
#
# ### $$E_v(t)  = \frac{\left|\sum_{c \in C}\alpha_c(t)|\Omega_c| - \sum_{c \in C} \alpha_c(t_0)|\Omega_c|\right|}{\left|\sum_{c \in C} \alpha_c(t_0)|\Omega_c|\right|}$$
#
# ###  Eg: L1 Geomeric error
#
# ### $$E_g = \sum_{c \in C} |\Omega_c||\alpha_c(t_e) - \alpha_c(t_0)|$$
#
# ### Eb: numerical boundedness
#
# **The method is unconditionally numerically stable (bounded).**

# %% [markdown]
# # Test case setup

# %%
R = 0.15 # Radius
V_e = 4*R**3 * pi / 3. # Exact volume

# %% [markdown]
# # Equidistant mesh
#
# ## Phase indicator (marker) - initial error

# %%
R = 0.15 # From the test case definition 
V_e = 4*R**3 * pi / 3.
plot_marker_error("3Ddeformation_000", exact_volume=V_e)
# Out:
# /usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   ndim = x[:, None].ndim
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %% [markdown]
# ## Advection errors

# %%
plot_advection_errors("3Dshear_000", radius=R)
# Out:
# /usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   ndim = x[:, None].ndim
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# Convergence order = 1.883744

# %% [markdown]
# # Perturbed mesh
#
# ## Phase indicator (marker) - initial error

# %%
plot_marker_error("3Dshear_000", exact_volume=V_e)

# %% [markdown]
# ## Advection errors

# %%
plot_advection_errors("3Dshear_perturbed_000", radius=R)
# Out:
# Convergence order = 0.889292

# %% [markdown]
# # Polyhedral mesh
#
# ## Phase indicator (marker) - initial error

# %%
plot_marker_error("3Dshear_poly_000", exact_volume=V_e)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-959e89285565> in <module>
# ----> 1 plot_marker_error("3Dshear_poly_000", exact_volume=V_e)
#
# /transfer/tomislav/leia-lecture-code/cases/advectionplot.py in plot_marker_error(study_pattern, exact_volume, csv_filename)
#      31 def plot_marker_error(study_pattern, exact_volume, csv_filename="leiaSetFields.csv"):
#      32
# ---> 33         marker_dframe = agglomerate_dframe(study_pattern, csv_filename,
#      34                                            dframe_name="marker")
#      35
#
# /transfer/tomislav/leia-lecture-code/cases/advectionplot.py in agglomerate_dframe(study_pattern, csv_filename, dframe_name)
#      25     for csv_file in csv_files:
#      26         dframes.append(pd.read_csv(csv_file, header=0))
# ---> 27     final_dframe = pd.concat(dframes, ignore_index=True)
#      28     final_dframe.to_csv(dframe_name + ".csv", index=False)
#      29     return final_dframe
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     292     ValueError: Indexes have overlapping values: ['a']
#     293     """
# --> 294     op = _Concatenator(
#     295         objs,
#     296         axis=axis,
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     349
#     350         if len(objs) == 0:
# --> 351             raise ValueError("No objects to concatenate")
#     352
#     353         if keys is None:
#
# ValueError: No objects to concatenate

# %% [markdown]
# ## Advection errors

# %%
plot_advection_errors("3Dshear_poly_000", radius=R)

# %% [markdown]
# # Tetrahedral mesh
#
# ## Phase indicator (marker) - initial error

# %%
plot_marker_error("3Dshear_tet_000", exact_volume=V_e)

# %% [markdown]
# ## Advection errors

# %%
plot_advection_errors("3Dshear_tet_000", radius=R)
